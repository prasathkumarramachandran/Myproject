# %%
# !pip install pandas
# Out:
# ...
# twisted 18.7.0 requires PyHamcrest>=1.9.0, which is not installed.

# %%
# !pip install PyHamcrest
# Out:
# ...
#   Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000002A24D647DD8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pyhamcrest/
#   Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000002A24D6477B8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pyhamcrest/
#   Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x000002A24D6476A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pyhamcrest/
# ...

# %%
import panda as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f542dbfa5144> in <module>()
# ----> 1 import panda as pd
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas as pd

# %%
import numby as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-f3edcc2f6a7d> in <module>()
# ----> 1 import numby as np
#
# ModuleNotFoundError: No module named 'numby'

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt from sklearn.preprocessing import Imputer
# Out:
#   File "<ipython-input-8-32639ab7aca6>", line 1
#     import matplotlib.pyplot as plt from sklearn.preprocessing import Imputer
#                                        ^
# SyntaxError: invalid syntax

# %%
pd.read_csv(Train_UWu5bXk.csv)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-47613564f000> in <module>()
# ----> 1 pd.read_csv(Train_UWu5bXk.csv)
#
# NameError: name 'Train_UWu5bXk' is not defined

# %%
pd.read_csv("Train_UWu5bXk.csv")
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
df = pd.read_csv("Train_UWu5bXk.csv")
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# ...

# %%
df = pd.read_json("Mobile Operators' Network stats-1538736063207.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-87556d0f0415> in <module>()
# ----> 1 df = pd.read_json("Mobile Operators' Network stats-1538736063207.json")
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     420         return json_reader
#     421
# --> 422     result = json_reader.read()
#     423     if should_close:
#     424         try:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\json\json.py in read(self)
#     527             )
#     528         else:
# --> 529             obj = self._get_object_parser(self.data)
#     530         self.close()
#     531         return obj
#
# ...

# %%
df = pd.read_csv("Train_UWu5bXk.csv")
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# ...

# %%
df.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
dimension = df.shape
dimension
# Out:
# (8523, 12)

# %%
data_type = df.dtypes

# %%
data_type
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\i067391\\Desktop\\DS_Phython\\workshopday2\\workshopday2'

# %%
median = df.median()
median
# Out:
# Item_Weight                    12.600000
# Item_Visibility                 0.053931
# Item_MRP                      143.012800
# Outlet_Establishment_Year    1999.000000
# Item_Outlet_Sales            1794.331000
# dtype: float64

# %%
mode = df.mode()
mode
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDG33        12.15          Low Fat              0.0
# 1           FDW13          NaN              NaN              NaN
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0  Fruits and Vegetables  172.0422            OUT027
# 1                    NaN       NaN               NaN
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                     1985.0      Medium               Tier 3
# 1                        NaN         NaN                  NaN
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1            958.752
# 1                NaN                NaN

# %%
median
mode
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDG33        12.15          Low Fat              0.0
# 1           FDW13          NaN              NaN              NaN
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0  Fruits and Vegetables  172.0422            OUT027
# 1                    NaN       NaN               NaN
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                     1985.0      Medium               Tier 3
# 1                        NaN         NaN                  NaN
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1            958.752
# 1                NaN                NaN

# %%
mode
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDG33        12.15          Low Fat              0.0
# 1           FDW13          NaN              NaN              NaN
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0  Fruits and Vegetables  172.0422            OUT027
# 1                    NaN       NaN               NaN
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                     1985.0      Medium               Tier 3
# 1                        NaN         NaN                  NaN
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1            958.752
# 1                NaN                NaN

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df("Outlet_Size") = df("Outlet_Size").fillna("Medium")
# Out:
#   File "<ipython-input-28-edb1fa713f45>", line 1
#     df("Outlet_Size") = df("Outlet_Size").fillna("Medium")
#                                                           ^
# SyntaxError: can't assign to function call

# %%
df["Outlet_Size"] = df["Outlet_Size"].fillna("Medium")

# %%
mean = round(df["Item_Weight"].mean(),1)

# %%
df["Item_Weight"] = df["Item_Weight"].fillna(mean)

# %%
df.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
dfbos = pd.read_csv("boston_csv.csv")
dfbos
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM         AGE     DIS  RAD  TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.199997  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.900002  4.9671    2  242
# 2     0.62976   0.0    NaN     0  0.538  5.949   61.799999  4.7075    4  307
# 3     0.02729   0.0   7.07     0  0.469  7.185   61.099998  4.9671    2  242
# 4     0.03237   0.0   2.18     0  0.458  6.998   45.799999  6.0622    3  222
# 5     0.06905   0.0   2.18     0  0.458  7.147   54.200001  6.0622    3  222
# 6     0.85204   0.0    NaN     0  0.538  5.965   89.199997  4.0123    4  307
# 7     0.02985   0.0   2.18     0  0.458  6.430   58.700001  6.0622    3  222
# 8     0.08829  12.5   7.87     0  0.524  6.012   66.599998  5.5605    5  311
# 9     0.14455  12.5   7.87     0  0.524  6.172   96.099998  5.9505    5  311
# 10    0.21124  12.5   7.87     0  0.524  5.631  100.000000  6.0821    5  311
# ...

# %%
dfbos.head
# Out:
# <bound method NDFrame.head of          CRIM    ZN  INDUS  CHAS    NOX     RM         AGE     DIS  RAD  TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.199997  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.900002  4.9671    2  242
# 2     0.62976   0.0    NaN     0  0.538  5.949   61.799999  4.7075    4  307
# 3     0.02729   0.0   7.07     0  0.469  7.185   61.099998  4.9671    2  242
# 4     0.03237   0.0   2.18     0  0.458  6.998   45.799999  6.0622    3  222
# 5     0.06905   0.0   2.18     0  0.458  7.147   54.200001  6.0622    3  222
# 6     0.85204   0.0    NaN     0  0.538  5.965   89.199997  4.0123    4  307
# 7     0.02985   0.0   2.18     0  0.458  6.430   58.700001  6.0622    3  222
# 8     0.08829  12.5   7.87     0  0.524  6.012   66.599998  5.5605    5  311
# 9     0.14455  12.5   7.87     0  0.524  6.172   96.099998  5.9505    5  311
# 10    0.21124  12.5   7.87     0  0.524  5.631  100.000000  6.0821    5  311
# ...

# %%
dfbos.isnull()
# Out:
#       CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False   True  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# 5    False  False  False  False  False  False  False  False  False  False
# 6    False  False   True  False  False  False  False  False  False  False
# 7    False  False  False  False  False  False  False  False  False  False
# 8    False  False  False  False  False  False  False  False  False  False
# 9    False  False  False  False  False  False  False  False  False  False
# 10   False  False  False  False  False  False  False  False  False  False
# 11   False  False  False  False  False  False  False  False  False  False
# ...

# %%
dfbos.isnull().sum()
# Out:
# CRIM      0
# ZN        0
# INDUS    11
# CHAS      0
# NOX       0
# RM        0
# AGE       0
# DIS       0
# RAD       0
# TAX       0
# PT        0
# B         0
# LSTAT     0
# MV        0
# dtype: int64

# %%
df["Item_weight","Item_Type"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Item_weight', 'Item_Type')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-7dd9b4663b9a> in <module>()
# ...

# %%
df["Item_weight"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Item_weight'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-ce06f2d510ea> in <module>()
# ...

# %%
df["Item_Weight"].value_counts()
# Out:
# 12.900    1463
# 12.150      86
# 17.600      82
# 13.650      77
# 11.800      76
# 15.100      68
# 9.300       68
# 10.500      66
# 16.700      66
# 19.350      63
# 20.700      62
# 16.000      62
# 9.800       61
# 17.700      60
# 17.750      60
# 18.850      59
# 15.850      59
# 15.000      59
# 18.250      58
# 19.600      58
# 16.750      58
# 15.700      57
# 12.500      56
# 9.195       56
# 20.200      53
# 10.195      53
# 12.100      53
# 12.600      53
# 15.600      52
# 11.500      51
#           ...
# 7.070        3
# 7.710        3
# 7.260        3
# 7.105        3
# 5.825        3
# 8.350        3
# 5.425        3
# 5.675        2
# 8.920        2
# 4.905        2
# 8.485        2
# 6.895        2
# 6.400        2
# 6.325        2
# 7.890        2
# 6.405        2
# 7.275        2
# 5.155        2
# 5.210        2
# 7.560        2
# 6.775        2
# 7.605        2
# 8.800        2
# 5.885        2
# 8.670        2
# 5.735        2
# 9.420        1
# ...

# %%
df["Item_weight","Item_Type"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Item_weight', 'Item_Type')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-7dd9b4663b9a> in <module>()
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.864916         0.066132   140.992782                1997.831867
# std       4.226154         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.900000         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-0e566b70f572> in <module>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  8523.000000      8523.000000  8523.000000                8523.000000
# mean     12.864916         0.066132   140.992782                1997.831867
# std       4.226154         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       9.310000         0.026989    93.826500                1987.000000
# 50%      12.900000         0.053931   143.012800                1999.000000
# 75%      16.000000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
ds.info
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-4fbf4afda395> in <module>()
# ----> 1 ds.info
#
# NameError: name 'ds' is not defined

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10       12.900          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# ...

# %%
df.boxplot(column="Item_Weight",by="Item_Type",figsize=(10,10),grid=True,rot=90)

# %%
df.["Item_Weight"].unique
# Out:
#   File "<ipython-input-52-79e58a0362a9>", line 1
#     df.["Item_Weight"].unique
#        ^
# SyntaxError: invalid syntax

# %%
# Out:
# <bound method Series.unique of 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
# 5       10.395
# 6       13.650
# 7       12.900
# 8       16.200
# 9       19.200
# 10      11.800
# 11      18.500
# 12      15.100
# 13      17.600
# 14      16.350
# 15       9.000
# 16      11.800
# 17       9.000
# 18      12.900
# 19      13.350
# 20      18.850
# 21      12.900
# 22      14.600
# 23      12.900
# 24      13.850
# 25      13.000
# 26       7.645
# 27      11.650
# 28       5.925
# 29      12.900
#          ...
# 8493     7.420
# 8494    15.200
# 8495     9.695
# 8496     7.420
# 8497    13.650
# 8498    15.350
# 8499    11.600
# 8500    20.350
# 8501     5.340
# 8502     8.420
# 8503    20.500
# 8504    12.900
# 8505    10.500
# 8506    17.250
# 8507     5.880
# 8508    11.350
# 8509     8.100
# 8510    13.800
# 8511    17.500
# 8512    20.700
# 8513    12.000
# 8514    15.000
# 8515    20.700
# 8516    18.600
# 8517    20.750
# 8518     6.865
# ...

# %%
df["Item_Weight"].unique
# Out:
# <bound method Series.unique of 0        9.300
# 1        5.920
# 2       17.500
# 3       19.200
# 4        8.930
# 5       10.395
# 6       13.650
# 7       12.900
# 8       16.200
# 9       19.200
# 10      11.800
# 11      18.500
# 12      15.100
# 13      17.600
# 14      16.350
# 15       9.000
# 16      11.800
# 17       9.000
# 18      12.900
# 19      13.350
# 20      18.850
# 21      12.900
# 22      14.600
# 23      12.900
# 24      13.850
# 25      13.000
# 26       7.645
# 27      11.650
# 28       5.925
# 29      12.900
#          ...
# 8493     7.420
# 8494    15.200
# 8495     9.695
# 8496     7.420
# 8497    13.650
# 8498    15.350
# 8499    11.600
# 8500    20.350
# 8501     5.340
# 8502     8.420
# 8503    20.500
# 8504    12.900
# 8505    10.500
# 8506    17.250
# 8507     5.880
# 8508    11.350
# 8509     8.100
# 8510    13.800
# 8511    17.500
# 8512    20.700
# 8513    12.000
# 8514    15.000
# 8515    20.700
# 8516    18.600
# 8517    20.750
# 8518     6.865
# ...

# %%
import seaborn as sea

# %%
data = pd.read_csv("KAG_Percent_of_Adult_diabetes__by_race_ethnicity_and_year.csv")

# %%
data.shape
# Out:
# (32, 7)

# %%
data.dimension
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-539e8f1385a0> in <module>()
# ----> 1 data.dimension
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dimension'

# %%
data.dimension()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-06bacbfd1396> in <module>()
# ----> 1 data.dimension()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dimension'

# %%
tot=data["Estimated Number of Adults Had Diabetes"]/data["Percent of Adults with Diabetes"]*100

# %%
tot
# Out:
# 0     7.760556e+06
# 1     6.538864e+06
# 2     3.982755e+05
# 3     5.976406e+05
# 4     8.039730e+06
# 5     6.218524e+06
# 6     3.945088e+05
# 7     6.287826e+05
# 8     8.026176e+06
# 9     6.591063e+06
# 10    3.691374e+05
# 11    6.435270e+05
# 12    8.156191e+06
# 13    6.591063e+06
# 14    3.691374e+05
# 15    6.435270e+05
# 16    8.133275e+06
# 17    6.651554e+06
# 18    3.560602e+05
# 19    5.942286e+05
# 20    8.143000e+06
# 21    6.564448e+06
# 22    3.721724e+05
# 23    5.929365e+05
# 24    5.391971e+06
# 25    4.422338e+06
# 26    2.566038e+05
# 27    3.941296e+05
# 28    5.558587e+06
# 29    4.040446e+06
# 30    5.650439e+05
# 31    6.563613e+05
# dtype: float64

# %%
data.shape
# Out:
# (32, 7)

# %%
data.head
# Out:
# <bound method NDFrame.head of                                       Demographic Data Years  \
# 0                       Connecticut adults (18+y)  2003-2005
# 1   White, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 2   Black, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 3              Hispanic Connecticut Adults (18+y)  2003-2005
# 4                       Connecticut adults (18+y)  2004-2006
# 5   White, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 6   Black, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 7              Hispanic Connecticut Adults (18+y)  2004-2006
# 8                       Connecticut adults (18+y)  2005-2007
# 9   White, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 10  Black, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 11             Hispanic Connecticut Adults (18+y)  2005-2007
# 12                      Connecticut adults (18+y)  2006-2008
# 13  White, non-Hispanic Connecticut Adults (18+y)  2006-2008
# ...

# %%
total=[]
for i in tot:
    a=round(i,0)
    total.append(a)
total_pop=pd.DataFrame(total)
data["total_pop"]=total_pop # created a new column total population
data.head()# It shows the 5 data points or rows
# Out:
#                                      Demographic Data Years  \
# 0                      Connecticut adults (18+y)  2003-2005
# 1  White, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 2  Black, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 3             Hispanic Connecticut Adults (18+y)  2003-2005
# 4                      Connecticut adults (18+y)  2004-2006
#
#    Estimated Number of Adults Had Diabetes  Percent of Adults with Diabetes  \
# 0                                   488915                              6.3
# 1                                   385793                              5.9
# 2                                    39031                              9.8
# 3                                    38249                              6.4
# 4                                   506503                              6.3
#
#    Standard Error for Percent  Coefficient of Variation (%)  \
# 0                        0.21                           3.3
# ...

# %%
data.hist(column="Percent of Adults with Diabetes",        # Column to plot
              figsize=(10,12),         # Plot size
              color="red",          # Plot color
              bins=100)               # Use 50 bins
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000187AA9C9898>]],
#       dtype=object)

# %%
data.hist(column="Percent of Adults with Diabetes",        # Column to plot
              figsize=(5,5),         # Plot size
              color="red",          # Plot color
              bins=20)               # Use 50 bins
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000187AA9D4A90>]],
#       dtype=object)

# %%
#Box plot
data.boxplot(column="Estimated Number of Adults Had Diabetes",        # Column to plot
                 by= "Demographic",         # Column to split upon
                 figsize= (8,8),rot=180,#to rotate the x-axis ticks to certain angle
                  grid=True)        # Figure size

# %%
#Box plot
data.boxplot(column="Estimated Number of Adults Had Diabetes",        # Column to plot
                 by= "Demographic",         # Column to split upon
                 figsize= (8,8),rot=180,#to rotate the x-axis ticks to certain angle
                  grid=True)        # Figure size

# %%
#Box plot
data.boxplot(column="Estimated Number of Adults Had Diabetes",        # Column to plot
                 by= "Demographic",         # Column to split upon
                 figsize= (20,20),rot=180,#to rotate the x-axis ticks to certain angle
                  grid=True)        # Figure size

# %%
data["Percent of Adults with Diabetes"].plot(kind="density",  # Create density plot
                      figsize=(8,8))   # Set figure size

# %%
sea.distplot(data["Percent of Adults with Diabetes"],#continous varible to be viewed
             hist=True,#if true histogram get displayed
             kde=True,#if true density line/graph get displayed 
             bins=int(10),#number of bins
             color = 'pink',#color of histogram and kde 
             hist_kws={'edgecolor':'orange'},#displyes edge colors of the histogram
             kde_kws={'linewidth': 2.5})#width of the density line
# Out:
# C:\Users\i067391\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#bar graph for single variable
data_table=pd.crosstab(index=data["Percent of Adults with Diabetes"],columns="count")
data_table.plot(kind="bar",figsize=(8,8))

# %%
#stacked bar chat
data_table = pd.crosstab(index=data["Percent of Adults with Diabetes"], 
                          columns=data["Demographic"])
 
data_table.plot(kind="bar",stacked=True,figsize=(8,8))

# %%
#pi-chart
data_2003_conn=data.loc[(data["Demographic"]=="Connecticut adults (18+y)")&(data["Data Years"]=="2003-2005")]
# Data to plot
labels=data_2003_conn["Estimated Number of Adults Had Diabetes"],data_2003_conn["total_pop"]-data_2003_conn["Estimated Number of Adults Had Diabetes"]
#sizes = [215, 130, 245, 210]
#colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

 
# Plot
plt.pie(labels=labels)
 
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-a8deaa5f2914> in <module>()
#       8
#       9 # Plot
# ---> 10 plt.pie(labels=labels)
#      11
#      12 plt.axis('equal')
#
# TypeError: pie() missing 1 required positional argument: 'x'

# %%
#pi-chart
data_2003_conn=data.loc[(data["Demographic"]=="Connecticut adults (18+y)")&(data["Data Years"]=="2003-2005")]
# Data to plot
labels=data_2003_conn["Estimated Number of Adults Had Diabetes"],data_2003_conn["total_pop"]-data_2003_conn["Estimated Number of Adults Had Diabetes"]
#sizes = [215, 130, 245, 210]
#colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

 
# Plot
plt.pie(labels=labels)
 
plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-a8deaa5f2914> in <module>()
#       8
#       9 # Plot
# ---> 10 plt.pie(labels=labels)
#      11
#      12 plt.axis('equal')
#
# TypeError: pie() missing 1 required positional argument: 'x'

# %%
#line graph(categorical-continous)
data_hisp=data.loc[(data["Demographic"]=="Hispanic Connecticut Adults (18+y)"),:] 
plt.plot(data_hisp["Data Years"],data_hisp["total_pop"])
plt.xticks(data_hisp["Data Years"],rotation="vertical")
# Out:
# ([<matplotlib.axis.XTick at 0x187ab7da4e0>,
# ...
#  <a list of 8 Text xticklabel objects>)

# %%
data.dimension
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-539e8f1385a0> in <module>()
# ----> 1 data.dimension
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dimension'

# %%
data.columns
# Out:
# Index(['Demographic', 'Data Years', 'Estimated Number of Adults Had Diabetes',
#        'Percent of Adults with Diabetes', 'Standard Error for Percent',
#        'Coefficient of Variation (%)', '95% Confidence Limits for Percent',
#        'total_pop'],
#       dtype='object')

# %%
data
# Out:
#                                       Demographic Data Years  \
# 0                       Connecticut adults (18+y)  2003-2005
# 1   White, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 2   Black, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 3              Hispanic Connecticut Adults (18+y)  2003-2005
# 4                       Connecticut adults (18+y)  2004-2006
# 5   White, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 6   Black, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 7              Hispanic Connecticut Adults (18+y)  2004-2006
# 8                       Connecticut adults (18+y)  2005-2007
# 9   White, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 10  Black, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 11             Hispanic Connecticut Adults (18+y)  2005-2007
# 12                      Connecticut adults (18+y)  2006-2008
# 13  White, non-Hispanic Connecticut Adults (18+y)  2006-2008
# ...

# %%
data["Demographic"] = "White, non-Hispanic Connecticut Adults (18+y)"

# %%
data["Demographic"]
# Out:
# 0     White, non-Hispanic Connecticut Adults (18+y)
# 1     White, non-Hispanic Connecticut Adults (18+y)
# 2     White, non-Hispanic Connecticut Adults (18+y)
# 3     White, non-Hispanic Connecticut Adults (18+y)
# 4     White, non-Hispanic Connecticut Adults (18+y)
# 5     White, non-Hispanic Connecticut Adults (18+y)
# 6     White, non-Hispanic Connecticut Adults (18+y)
# 7     White, non-Hispanic Connecticut Adults (18+y)
# 8     White, non-Hispanic Connecticut Adults (18+y)
# 9     White, non-Hispanic Connecticut Adults (18+y)
# 10    White, non-Hispanic Connecticut Adults (18+y)
# 11    White, non-Hispanic Connecticut Adults (18+y)
# 12    White, non-Hispanic Connecticut Adults (18+y)
# 13    White, non-Hispanic Connecticut Adults (18+y)
# 14    White, non-Hispanic Connecticut Adults (18+y)
# 15    White, non-Hispanic Connecticut Adults (18+y)
# 16    White, non-Hispanic Connecticut Adults (18+y)
# 17    White, non-Hispanic Connecticut Adults (18+y)
# ...

# %%
data
# Out:
#                                       Demographic Data Years  \
# 0   White, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 1   White, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 2   White, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 3   White, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 4   White, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 5   White, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 6   White, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 7   White, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 8   White, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 9   White, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 10  White, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 11  White, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 12  White, non-Hispanic Connecticut Adults (18+y)  2006-2008
# 13  White, non-Hispanic Connecticut Adults (18+y)  2006-2008
# ...

# %%
data = pd.read_csv("KAG_Percent_of_Adult_diabetes__by_race_ethnicity_and_year.csv")

# %%
data
# Out:
#                                       Demographic Data Years  \
# 0                       Connecticut adults (18+y)  2003-2005
# 1   White, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 2   Black, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 3              Hispanic Connecticut Adults (18+y)  2003-2005
# 4                       Connecticut adults (18+y)  2004-2006
# 5   White, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 6   Black, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 7              Hispanic Connecticut Adults (18+y)  2004-2006
# 8                       Connecticut adults (18+y)  2005-2007
# 9   White, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 10  Black, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 11             Hispanic Connecticut Adults (18+y)  2005-2007
# 12                      Connecticut adults (18+y)  2006-2008
# 13  White, non-Hispanic Connecticut Adults (18+y)  2006-2008
# ...

# %%
total=[]
for i in tot:
    a=round(i,0)
    total.append(a)
total_pop=pd.DataFrame(total)
data["total_pop"]=total_pop # created a new column total population
data.head()# It shows the 5 data points or rows
# Out:
#                                      Demographic Data Years  \
# 0                      Connecticut adults (18+y)  2003-2005
# 1  White, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 2  Black, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 3             Hispanic Connecticut Adults (18+y)  2003-2005
# 4                      Connecticut adults (18+y)  2004-2006
#
#    Estimated Number of Adults Had Diabetes  Percent of Adults with Diabetes  \
# 0                                   488915                              6.3
# 1                                   385793                              5.9
# 2                                    39031                              9.8
# 3                                    38249                              6.4
# 4                                   506503                              6.3
#
#    Standard Error for Percent  Coefficient of Variation (%)  \
# 0                        0.21                           3.3
# ...

# %%
data
# Out:
#                                       Demographic Data Years  \
# 0                       Connecticut adults (18+y)  2003-2005
# 1   White, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 2   Black, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 3              Hispanic Connecticut Adults (18+y)  2003-2005
# 4                       Connecticut adults (18+y)  2004-2006
# 5   White, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 6   Black, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 7              Hispanic Connecticut Adults (18+y)  2004-2006
# 8                       Connecticut adults (18+y)  2005-2007
# 9   White, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 10  Black, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 11             Hispanic Connecticut Adults (18+y)  2005-2007
# 12                      Connecticut adults (18+y)  2006-2008
# 13  White, non-Hispanic Connecticut Adults (18+y)  2006-2008
# ...

# %%
data.plot.hexbin(y="Estimated Number of Adults Had Diabetes",x="total_pop",gridsize=5)

# %%
data.plot.hexbin(y="total_pop",x="Estimated Number of Adults Had Diabetes",gridsize=5)

# %%
data.plot.hexbin(y="95% Confidence Limits for Percent",x="total_pop",gridsize=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-599dbcfd9d95> in <module>()
# ----> 1 data.plot.hexbin(y="95% Confidence Limits for Percent",x="total_pop",gridsize=5)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in hexbin(self, x, y, C, reduce_C_function, gridsize, **kwds)
#    3548         if gridsize is not None:
#    3549             kwds['gridsize'] = gridsize
# -> 3550         return self(kind='hexbin', x=x, y=y, C=C, **kwds)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
# ...

# %%
data.dimension
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-539e8f1385a0> in <module>()
# ----> 1 data.dimension
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dimension'

# %%
data.info
# Out:
# <bound method DataFrame.info of                                       Demographic Data Years  \
# 0                       Connecticut adults (18+y)  2003-2005
# 1   White, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 2   Black, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 3              Hispanic Connecticut Adults (18+y)  2003-2005
# 4                       Connecticut adults (18+y)  2004-2006
# 5   White, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 6   Black, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 7              Hispanic Connecticut Adults (18+y)  2004-2006
# 8                       Connecticut adults (18+y)  2005-2007
# 9   White, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 10  Black, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 11             Hispanic Connecticut Adults (18+y)  2005-2007
# 12                      Connecticut adults (18+y)  2006-2008
# 13  White, non-Hispanic Connecticut Adults (18+y)  2006-2008
# ...

# %%
data.head
# Out:
# <bound method NDFrame.head of                                       Demographic Data Years  \
# 0                       Connecticut adults (18+y)  2003-2005
# 1   White, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 2   Black, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 3              Hispanic Connecticut Adults (18+y)  2003-2005
# 4                       Connecticut adults (18+y)  2004-2006
# 5   White, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 6   Black, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 7              Hispanic Connecticut Adults (18+y)  2004-2006
# 8                       Connecticut adults (18+y)  2005-2007
# 9   White, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 10  Black, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 11             Hispanic Connecticut Adults (18+y)  2005-2007
# 12                      Connecticut adults (18+y)  2006-2008
# 13  White, non-Hispanic Connecticut Adults (18+y)  2006-2008
# ...

# %%
data.dtypes
# Out:
# Demographic                                 object
# Data Years                                  object
# Estimated Number of Adults Had Diabetes      int64
# Percent of Adults with Diabetes            float64
# Standard Error for Percent                 float64
# Coefficient of Variation (%)               float64
# 95% Confidence Limits for Percent           object
# total_pop                                  float64
# dtype: object

# %%
sea.lmplot(x='Estimated Number of Adults Had Diabetes', y='Percent of Adults with Diabetes', hue='Demographic', 
           data=data, 
           fit_reg=True
# Out:
#   File "<ipython-input-96-ae0bf0d84961>", line 3
#     fit_reg=True
#                 ^
# SyntaxError: unexpected EOF while parsing

# %%
sea.lmplot(x='Estimated Number of Adults Had Diabetes', y='Percent of Adults with Diabetes', hue='Demographic', 
           data=data, 
           fit_reg=True)
# Out:
# C:\Users\i067391\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sea.lmplot(x='Item_MRP', y='Item_Outlet_Sales',hue='Outlet_Size', col="Item_Fat_Content",col_wrap=2,
           data=data2, 
           fit_reg=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-f3008de2434e> in <module>()
#       1 sea.lmplot(x='Item_MRP', y='Item_Outlet_Sales',hue='Outlet_Size', col="Item_Fat_Content",col_wrap=2,
# ----> 2            data=data2,
#       3            fit_reg=True)
#
# NameError: name 'data2' is not defined

# %%
sea.lmplot(x='Item_MRP', y='Item_Outlet_Sales',hue='Outlet_Size', col="Item_Fat_Content",col_wrap=2,
           data=data, 
           fit_reg=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-20312da9db2f> in <module>()
#       1 sea.lmplot(x='Item_MRP', y='Item_Outlet_Sales',hue='Outlet_Size', col="Item_Fat_Content",col_wrap=2,
#       2            data=data,
# ----> 3            fit_reg=True)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\seaborn\regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, size)
#     549     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
#     550     cols = np.unique([a for a in need_cols if a is not None]).tolist()
# --> 551     data = data[cols]
#     552
# ...

# %%
corr = data.corr()
sea.heatmap(corr)

# %%
corr = ds.corr()
sea.heatmap(corr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-102-ccf32ae956fc> in <module>()
# ----> 1 corr = ds.corr()
#       2 sea.heatmap(corr)
#
# NameError: name 'ds' is not defined

# %%
corr = df.corr()
sea.heatmap(corr)

# %%
df.corr
# Out:
# <bound method DataFrame.corr of      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10       12.900          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# ...

# %%
data.corr()
# Out:
#                                          Estimated Number of Adults Had Diabetes  \
# Estimated Number of Adults Had Diabetes                                 1.000000
# Percent of Adults with Diabetes                                        -0.522582
# Standard Error for Percent                                             -0.864633
# Coefficient of Variation (%)                                           -0.958323
# total_pop                                                               0.988693
#
#                                          Percent of Adults with Diabetes  \
# Estimated Number of Adults Had Diabetes                        -0.522582
# Percent of Adults with Diabetes                                 1.000000
# Standard Error for Percent                                      0.840035
# Coefficient of Variation (%)                                    0.490914
# total_pop                                                      -0.583047
#
# ...

# %%
# coding: utf-8

# In[2]:


#Imputation of data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


# In[3]:


# Reading the csv file
train=pd.read_csv("Train_UWu5bXk.csv")
train.head()


# In[4]:


train.isnull().sum()


# In[5]:


# Imputation of the values
train["Outlet_Size"]=train["Outlet_Size"].fillna("Medium")
train["Outlet_Establishment_Year"]=train["Outlet_Establishment_Year"].fillna(1985)
mean1=round(train["Item_Weight"].mean(),1)
train["Item_Weight"]=train["Item_Weight"].fillna(mean1)
train


# ## Backward feature elimination

# In[7]:


# drop the target variable
df=train.drop(["Item_Outlet_Sales"],1)


# In[10]:


df=train.drop(['Item_Identifier', 'Outlet_Identifier'], axis=1)
df.head()


# In[11]:


# converting string values to numeric
df=pd.get_dummies(df)


# In[12]:


df.head()


# In[13]:


from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn import datasets
lreg = LinearRegression()
rfe = RFE(lreg,4)
rfe = rfe.fit_transform(df, train.Item_Outlet_Sales)
# (RFE=Recursive feature elimination)


# In[14]:


rfe


# ## Forward Feature Selection

# In[16]:


from sklearn.feature_selection import f_regression
ffs = f_regression(df,train.Item_Outlet_Sales )


# In[17]:


# This returns an array containing the F-values of the variables and the p-values corresponding to each F value. 
ffs


# In[18]:


# selecting the variables having F-value greater than 10:
variable = [ ]
for i in range(0,len(df.columns)-1):
    if ffs[0][i] >=10:
       variable.append(df.columns[i])


# In[19]:


# top most variables based on the forward feature selection algorithm.
variable


# ## Factor Analysis

# In[20]:


from factor_analyzer import FactorAnalyzer
fa = FactorAnalyzer()


# In[28]:


fa.analyze(train, 3, rotation=None)


# In[29]:


fa.loadings


# In[30]:


fa.get_uniqueness()
# we have to select which feature have the heighest uniqueness value that feature is the first importent variable


# ## Principle component Analysis

# In[31]:


from sklearn.decomposition import PCA
pca = PCA(n_components=4)
principalComponents = pca.fit_transform(df)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2','principal component 3','principal component 4'])


# In[32]:


principalDf


# In[33]:


finalDf = pd.concat([principalDf, df[['Item_Outlet_Sales']]], axis = 1)


# In[35]:


finalDf.head()


# In[36]:


pca.explained_variance_ratio_


# In[37]:


plt.plot(range(4), pca.explained_variance_ratio_)
plt.plot(range(4), np.cumsum(pca.explained_variance_ratio_))
plt.title("Component-wise and Cumulative Explained Variance")
# in the output:
# blue line represents component-wise explained variance
# orange line represents the cumulative explained variance
# We are able to explain around 99% variance in the dataset using 4 components
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-106-27bb498ef28b> in <module>()
#     121
#     122
# --> 123 from factor_analyzer import FactorAnalyzer
#     124 fa = FactorAnalyzer()
#     125
#
# ModuleNotFoundError: No module named 'factor_analyzer'

# %%
data
# Out:
#                                       Demographic Data Years  \
# 0                       Connecticut adults (18+y)  2003-2005
# 1   White, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 2   Black, non-Hispanic Connecticut Adults (18+y)  2003-2005
# 3              Hispanic Connecticut Adults (18+y)  2003-2005
# 4                       Connecticut adults (18+y)  2004-2006
# 5   White, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 6   Black, non-Hispanic Connecticut Adults (18+y)  2004-2006
# 7              Hispanic Connecticut Adults (18+y)  2004-2006
# 8                       Connecticut adults (18+y)  2005-2007
# 9   White, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 10  Black, non-Hispanic Connecticut Adults (18+y)  2005-2007
# 11             Hispanic Connecticut Adults (18+y)  2005-2007
# 12                      Connecticut adults (18+y)  2006-2008
# 13  White, non-Hispanic Connecticut Adults (18+y)  2006-2008
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_componentns = 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-78eba0f63ea8> in <module>()
# ----> 1 pca = PCA(n_componentns = 4)
#
# TypeError: __init__() got an unexpected keyword argument 'n_componentns'

# %%
# !pip install sklearn.decomposition
# Out:
# ...
#   Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x0000024433C647F0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sklearn-decomposition/
#   Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x0000024433C64908>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sklearn-decomposition/
#   Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x0000024433C646D8>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/sklearn-decomposition/
# ...

# %%
data = pd.read_csv("boston_csv.csv")

# %%
data
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM         AGE     DIS  RAD  TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.199997  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.900002  4.9671    2  242
# 2     0.62976   0.0    NaN     0  0.538  5.949   61.799999  4.7075    4  307
# 3     0.02729   0.0   7.07     0  0.469  7.185   61.099998  4.9671    2  242
# 4     0.03237   0.0   2.18     0  0.458  6.998   45.799999  6.0622    3  222
# 5     0.06905   0.0   2.18     0  0.458  7.147   54.200001  6.0622    3  222
# 6     0.85204   0.0    NaN     0  0.538  5.965   89.199997  4.0123    4  307
# 7     0.02985   0.0   2.18     0  0.458  6.430   58.700001  6.0622    3  222
# 8     0.08829  12.5   7.87     0  0.524  6.012   66.599998  5.5605    5  311
# 9     0.14455  12.5   7.87     0  0.524  6.172   96.099998  5.9505    5  311
# 10    0.21124  12.5   7.87     0  0.524  5.631  100.000000  6.0821    5  311
# ...

# %%
df = data.drop(["MV"]),axis=1)
df.head
# Out:
#   File "<ipython-input-114-41556c5a8611>", line 1
#     df = data.drop(["MV"]),axis=1)
#                                  ^
# SyntaxError: invalid syntax

# %%
df = data.drop(["MV"],axis=1)
df.head
# Out:
# <bound method NDFrame.head of          CRIM    ZN  INDUS  CHAS    NOX     RM         AGE     DIS  RAD  TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.199997  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.900002  4.9671    2  242
# 2     0.62976   0.0    NaN     0  0.538  5.949   61.799999  4.7075    4  307
# 3     0.02729   0.0   7.07     0  0.469  7.185   61.099998  4.9671    2  242
# 4     0.03237   0.0   2.18     0  0.458  6.998   45.799999  6.0622    3  222
# 5     0.06905   0.0   2.18     0  0.458  7.147   54.200001  6.0622    3  222
# 6     0.85204   0.0    NaN     0  0.538  5.965   89.199997  4.0123    4  307
# 7     0.02985   0.0   2.18     0  0.458  6.430   58.700001  6.0622    3  222
# 8     0.08829  12.5   7.87     0  0.524  6.012   66.599998  5.5605    5  311
# 9     0.14455  12.5   7.87     0  0.524  6.172   96.099998  5.9505    5  311
# 10    0.21124  12.5   7.87     0  0.524  5.631  100.000000  6.0821    5  311
# ...

# %%
pca = PCA(n_components = 4)
Prin = pca.fit_transform(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-fa729915125c> in <module>()
#       1 pca = PCA(n_components = 4)
# ----> 2 Prin = pca.fit_transform(df)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\decomposition\pca.py in fit_transform(self, X, y)
#     346
#     347         """
# --> 348         U, S, V = self._fit(X)
#     349         U = U[:, :self.n_components_]
#     350
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\decomposition\pca.py in _fit(self, X)
#     368
#     369         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 370                         copy=self.copy)
#     371
#     372         # Handle n_components==None
#
# ...

# %%
df.isnull().sum()
# Out:
# CRIM      0
# ZN        0
# INDUS    11
# CHAS      0
# NOX       0
# RM        0
# AGE       0
# DIS       0
# RAD       0
# TAX       0
# PT        0
# B         0
# LSTAT     0
# dtype: int64

# %%
df.head
# Out:
# <bound method NDFrame.head of          CRIM    ZN  INDUS  CHAS    NOX     RM         AGE     DIS  RAD  TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.199997  4.0900    1  296
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.900002  4.9671    2  242
# 2     0.62976   0.0    NaN     0  0.538  5.949   61.799999  4.7075    4  307
# 3     0.02729   0.0   7.07     0  0.469  7.185   61.099998  4.9671    2  242
# 4     0.03237   0.0   2.18     0  0.458  6.998   45.799999  6.0622    3  222
# 5     0.06905   0.0   2.18     0  0.458  7.147   54.200001  6.0622    3  222
# 6     0.85204   0.0    NaN     0  0.538  5.965   89.199997  4.0123    4  307
# 7     0.02985   0.0   2.18     0  0.458  6.430   58.700001  6.0622    3  222
# 8     0.08829  12.5   7.87     0  0.524  6.012   66.599998  5.5605    5  311
# 9     0.14455  12.5   7.87     0  0.524  6.172   96.099998  5.9505    5  311
# 10    0.21124  12.5   7.87     0  0.524  5.631  100.000000  6.0821    5  311
# ...

# %%
df = data.drop(["INDUS"]),axis=1)
# Out:
#   File "<ipython-input-119-8ca1dbe0f721>", line 1
#     df = data.drop(["INDUS"]),axis=1)
#                                     ^
# SyntaxError: invalid syntax

# %%
dfnew = df.drop(["MV"]),axis=1)
# Out:
#   File "<ipython-input-120-8e44f40375a6>", line 1
#     dfnew = df.drop(["MV"]),axis=1)
#                                   ^
# SyntaxError: invalid syntax

# %%
df = data.drop(["INDUS"]),axis=1)
# Out:
#   File "<ipython-input-122-8ca1dbe0f721>", line 1
#     df = data.drop(["INDUS"]),axis=1)
#                                     ^
# SyntaxError: invalid syntax

# %%
 dfnew = df.drop(["INDUS"],axis=1)

# %%
pca = PCA(n_components = 4)
Prin = pca.fit_transform(dfnew)

# %%
Prin
# Out:
# array([[-1.19517210e+02, -5.50088654e+00, -3.29506580e+00,
#          5.21877791e+00],
#        [-1.68875458e+02,  9.91204305e+00, -3.03629532e+01,
#          1.09301986e+00],
#        [-1.08294000e+02, -8.68017078e+00, -1.14196888e+01,
#         -1.11145337e+01],
#        ...,
#        [ 2.34494076e+02, -1.11630895e+02,  2.41333436e+01,
#         -2.09364841e+01],
#        [ 2.36523125e+02, -1.11797343e+02,  3.28075524e+00,
#         -3.85439326e+00],
#        [ 2.37436177e+02, -1.10344541e+02, -1.46563759e+00,
#          2.03241977e-01]])

# %%
Prinnew = pd.DataFrame(data = Prin,columns = ['pc1','pc2','pc3','pc4'])

# %%
Prinnew.head
# Out:
# <bound method NDFrame.head of             pc1         pc2        pc3        pc4
# 0   -119.517210   -5.500887  -3.295066   5.218778
# 1   -168.875458    9.912043 -30.362953   1.093020
# 2   -108.294000   -8.680171 -11.419689 -11.114534
# 3   -169.298115   13.853447 -16.209559 -10.398091
# 4   -190.095420   17.909776  -6.247086 -19.765012
# 5   -189.995683   15.715490 -12.930445 -14.337679
# 6   -104.650366   -4.572103 -32.769604   6.427404
# 7   -188.834278   18.358524 -16.288923 -11.520151
# 8   -104.170128   -8.556756  -7.070613   1.833530
# 9   -101.957755   -9.882541 -30.211840  20.781652
# 10   -98.457946    0.005909 -33.950447  23.691733
# 11   -99.939856   -0.091359 -21.973125  14.198793
# 12  -100.826846   -5.670605 -28.839710  19.688484
# 13  -104.192625   -6.504099 -41.618500  13.539143
# 14  -103.181988   -9.864181 -19.582275  12.174126
# 15  -104.913839   -3.536509  13.787633 -15.468700
# 16  -108.294000   -8.680171 -11.419689 -11.114534
# ...

# %%
Prinnew.explained_variance_ratio_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-130-687aaa007e33> in <module>()
# ----> 1 Prinnew.explained_variance_ratio_
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'explained_variance_ratio_'

# %%
Prin.explained_variance_ratio_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-131-125b0ce3b2a0> in <module>()
# ----> 1 Prin.explained_variance_ratio_
#
# AttributeError: 'numpy.ndarray' object has no attribute 'explained_variance_ratio_'

# %%
pca.explained_variance_ratio_
# Out:
# array([0.80675366, 0.16277356, 0.02116904, 0.00691485])

# %%
df = pd.read_csv("Train_UWu5bXk.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# ...

# %%
df["Item_Weight"].plot(kind="density",  # Create density plot
                      figsize=(8,8))   # Set figure size

# %%
df["Item_mrp"].plot(kind="density",  # Create density plot
                      figsize=(8,8))   # Set figure size
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Item_mrp'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-136-ddd0b0dada66> in <module>()
# ...

# %%
df.columns
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
df["Item_MRP"].plot(kind="density",  # Create density plot
                      figsize=(8,8))   # Set figure size

# %%
X = df.iloc[:, [3,5]].values

from sklearn.cluster import KMeans

kmeanss = KMeans(n_clusters=4) 

kmeans = kmeanss.fit_predict(X)

print('K Means cluster centers', kmeanss.cluster_centers_)
# Out:
# K Means cluster centers [[6.70084768e-02 5.23661187e+01]
#  [6.63150023e-02 1.69606993e+02]
#  [6.50487434e-02 1.06991842e+02]
#  [6.67248886e-02 2.37538948e+02]]

# %%
X = df.iloc[:, [3,5,7]].values

from sklearn.cluster import KMeans

kmeanss = KMeans(n_clusters=4) 

kmeans = kmeanss.fit_predict(X)

print('K Means cluster centers', kmeanss.cluster_centers_)
# Out:
# K Means cluster centers [[6.50231740e-02 1.06981139e+02 1.99788954e+03]
#  [6.67248886e-02 2.37538948e+02 1.99795101e+03]
#  [6.70517360e-02 5.23484310e+01 1.99780568e+03]
#  [6.63150023e-02 1.69606993e+02 1.99773975e+03]]

# %%
X = df.iloc[:, [5,7,10,11]].values

from sklearn.cluster import KMeans

kmeanss = KMeans(n_clusters=4) 

kmeans = kmeanss.fit_predict(X)

print('K Means cluster centers', kmeanss.cluster_centers_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-689b3a3995b3> in <module>()
#       5 kmeanss = KMeans(n_clusters=4)
#       6
# ----> 7 kmeans = kmeanss.fit_predict(X)
#       8
#       9 print('K Means cluster centers', kmeanss.cluster_centers_)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in fit_predict(self, X, y)
#     915             Index of the cluster each sample belongs to.
#     916         """
# --> 917         return self.fit(X).labels_
#     918
#     919     def fit_transform(self, X, y=None):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y)
#     885         """
#     886         random_state = check_random_state(self.random_state)
# --> 887         X = self._check_fit_data(X)
#     888
# ...

# %%
import os
import pandas as pd
import numpy as np
df = pd.read_csv("Train_UWu5bXk.csv")
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 10             FDY07       11.800          Low Fat         0.000000
# 11             FDA03       18.500          Regular         0.045464
# 12             FDX32       15.100          Regular         0.100014
# ...

# %%
#clustering
X = df.iloc[:, [3,5]].values

from sklearn.cluster import KMeans

kmeanss = KMeans(n_clusters=3) 

kmeans = kmeanss.fit_predict(X)

print('K Means cluster centers', kmeanss.cluster_centers_)
# Out:
# K Means cluster centers [[6.58532401e-02 8.19198341e+01]
#  [6.67248886e-02 2.37538948e+02]
#  [6.61865332e-02 1.64791008e+02]]

# %%
#Classification
t=pd.DataFrame(df.query("Outlet_Type=='Supermarket Type1' or Outlet_Type=='Grocery Store'")['Outlet_Type'])

X=pd.DataFrame(df.query("Outlet_Type=='Supermarket Type1' or Outlet_Type=='Grocery Store'")['Item_Visibility'])
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression
X_train, X_test, t_train, t_test = train_test_split(X, t,
                                                    test_size=0.3,
                                                    random_state=10)

logreg=LogisticRegression()
logreg.fit(X_train,t_train)
predicted_entropy = logreg .predict(X_test)
#Confusion Matrix
from  sklearn.metrics import confusion_matrix 
cM = confusion_matrix(t_test,predicted_entropy)
print(cM)

from sklearn.metrics import accuracy_score
print("Accuracy is", accuracy_score(t_test,predicted_entropy))

print("Coefficients of Regression are",logreg.coef_)
print("Intercept is", logreg.intercept_)
# Out:
# [[  12  332]
#  [   0 1654]]
# Accuracy is 0.8338338338338338
# Coefficients of Regression are [[-9.26678241]]
# Intercept is [2.37459899]
# C:\Users\i067391\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\i067391\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
type(X)
# Out:
# numpy.ndarray

# %%
type(t)
# Out:
# pandas.core.series.Series
