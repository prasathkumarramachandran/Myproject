# %%
how_many_snakes = 1
snake_string = """
Welcome to Python3!

             ____
            / . .\\
            \  ---<
             \  /
   __________/ /
-=:___________/

<3, Juno
"""
print(snake_string * how_many_snakes)
# Out:
# Welcome to Python3!
#
#              ____
#             / . .\
#             \  ---<
#              \  /
#    __________/ /
# -=:___________/
#
# <3, Juno

# %%
name = input("Enter your name: ")
print("Hello there, {}!".format(name.title()))
# Out:
# Enter your name: Prasath
# Hello there, Prasath!

# %%
names = input("Enter names separated by commas: ").title().split(",")
assignments = input("Enter assignment counts separated by commas: ").split(",")
grades = input("Enter grades separated by commas: ").split(",")

message = "Hi {},\n\nThis is a reminder that you have {} assignments left to \
submit before you can graduate. You're current grade is {} and can increase \
to {} if you submit all assignments before the due date.\n\n"

for name, assignment, grade in zip(names, assignments, grades):
    print(message.format(name, assignment, grade, int(grade) + int(assignment)*2))
# Out:
# Enter names separated by commas: Sabita, Avijit, Mrina
# Enter assignment counts separated by commas: 80, 45, 78
# Enter grades separated by commas: 4, 40, 6
# Hi Sabita,
#
# This is a reminder that you have 80 assignments left to submit before you can graduate. You're current grade is 4 and can increase to 164 if you submit all assignments before the due date.
#
#
# Hi  Avijit,
#
# This is a reminder that you have  45 assignments left to submit before you can graduate. You're current grade is  40 and can increase to 130 if you submit all assignments before the due date.
#
#
# Hi  Mrina,
#
# This is a reminder that you have  78 assignments left to submit before you can graduate. You're current grade is  6 and can increase to 162 if you submit all assignments before the due date.

# %%
import math

# %%
math.exp(3)
# Out:
# 20.085536923187668
